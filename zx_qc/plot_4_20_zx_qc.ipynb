# %%
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# ## 4 Qubits, 20 Depth

# %%
df_dg = pd.read_pickle("/home/hinog/src/python3/pyzx_utils/zx_qc/data/pkl/4_20_zxdiagram.pkl")
df_qc = pd.read_pickle("/home/hinog/src/python3/pyzx_utils/zx_qc/data/pkl/4_20_qc.pkl")
df_qc1 = pd.read_pickle("/home/hinog/src/python3/pyzx_utils/zx_qc/data/pkl/4_20_qc1.pkl")

# %% [markdown]
# ### num_gates in QC と zx の特徴量の関係性

# %%
x_column = 'num_edge'  # x軸にしたい列名
y_column = 'num_gates'  # y軸にしたい列名

plt.scatter(df_dg[x_column], df_qc[y_column], s=10)
plt.xlabel(f'{x_column} in zx')
plt.ylabel(f'{y_column} in qc')
plt.show()

#相関係数の計算
correlation = df_dg[x_column].corr(df_qc[y_column])
print(correlation)
# Out:
# 0.8983940154192193

# %%
x_column = 'num_vertices'  # x軸にしたい列名
y_column = 'num_gates'  # y軸にしたい列名

plt.scatter(df_dg[x_column], df_qc[y_column], s=10)
plt.xlabel(f'{x_column} in zx')
plt.ylabel(f'{y_column} in qc')
plt.show()
correlation = df_dg[x_column].corr(df_qc[y_column])
print(correlation)
# Out:
# 0.8938499681863628

# %%
x_column = 'num_edge_and_vertices'  # x軸にしたい列名
y_column = 'num_gates'  # y軸にしたい列名

plt.scatter(df_dg[x_column], df_qc[y_column], s=10)
plt.xlabel(f'{x_column} in zx')
plt.ylabel(f'{y_column} in qc')
plt.show()

correlation = df_dg[x_column].corr(df_qc[y_column])
print(correlation)
# Out:
# 0.9132666695897136

# %% [markdown]
# ### num_2qgates in QC と zx の特徴量の関係性

# %%
x_column = 'num_edge'  # x軸にしたい列名
y_column = 'num_2qgates'  # y軸にしたい列名

plt.scatter(df_dg[x_column], df_qc[y_column], s=10)
plt.xlabel(f'{x_column} in zx')
plt.ylabel(f'{y_column} in qc')
plt.show()

correlation = df_dg[x_column].corr(df_qc[y_column])
print(correlation)
# Out:
# 0.8116755993741542

# %%
x_column = 'num_verticallyconnected_edges'  # x軸にしたい列名
y_column = 'num_2qgates'  # y軸にしたい列名

plt.scatter(df_dg[x_column], df_qc[y_column], s=10)
plt.xlabel(f'{x_column} in zx')
plt.ylabel(f'{y_column} in qc')
plt.show()

correlation = df_dg[x_column].corr(df_qc[y_column])
print(correlation)
# Out:
# 1.0

# %% [markdown]
# ### num_noncliffords gates in qc と zx 特徴量の関係

# %%
x_column = 'num_noncliffordsphase_vertices'  # x軸にしたい列名
y_column = 'num_noncliffordsgates'  # y軸にしたい列名

plt.scatter(df_dg[x_column], df_qc[y_column], s=10)
plt.xlabel(f'{x_column} in zx')
plt.ylabel(f'{y_column} in qc')
plt.show()

correlation = df_dg[x_column].corr(df_qc[y_column])
print(correlation)
# Out:
# 1.0

# %% [markdown]
# ### num H gates in QC と zx 特徴量の関係

# %%
x_column = 'num_edge'  # x軸にしたい列名
y_column = 'num_hadamardgates'  # y軸にしたい列名

plt.scatter(df_dg[x_column], df_qc[y_column], s=10)
plt.xlabel(f'{x_column} in zx')
plt.ylabel(f'{y_column} in qc')
plt.show()

correlation = df_dg[x_column].corr(df_qc[y_column])
print(correlation)
# Out:
# 0.8506056255219492

# %%
x_column = 'num_vertices'  # x軸にしたい列名
y_column = 'num_hadamardgates'  # y軸にしたい列名

plt.scatter(df_dg[x_column], df_qc[y_column], s=10)
plt.xlabel(f'{x_column} in zx')
plt.ylabel(f'{y_column} in qc')
plt.show()

correlation = df_dg[x_column].corr(df_qc[y_column])
print(correlation)
# Out:
# 0.8852234376148801

# %%
x_column = 'num_edge_and_vertices'  # x軸にしたい列名
y_column = 'num_hadamardgates'  # y軸にしたい列名

plt.scatter(df_dg[x_column], df_qc[y_column], s=10)
plt.xlabel(f'{x_column} in zx')
plt.ylabel(f'{y_column} in qc')
plt.show()

correlation = df_dg[x_column].corr(df_qc[y_column])
print(correlation)
# Out:
# 0.880847154800765
