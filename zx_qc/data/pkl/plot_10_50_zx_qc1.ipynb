# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# ## 10 Qubits, 50 Depth

# %%
df_dg = pd.read_pickle("/home/hinog/src/python3/pyzx_utils/zx_qc/data/pkl/10_50_zxdiagram.pkl")
df_qc = pd.read_pickle("/home/hinog/src/python3/pyzx_utils/zx_qc/data/pkl/10_50_qc.pkl")
df_qc1 = pd.read_pickle("/home/hinog/src/python3/pyzx_utils/zx_qc/data/pkl/10_50_qc1.pkl")

# %% [markdown]
# ### num_gates in QC と zx の特徴量の関係性

# %%
x_column = 'num_edge'  # x軸にしたい列名
y_column = 'num_gates'  # y軸にしたい列名


plt.scatter(df_dg[x_column], df_qc1[y_column], s=10)
plt.xlabel(f'{x_column} in zx')
plt.ylabel(f'{y_column} in qc')

# 1次関数の近似
coefficients = np.polyfit(df_dg[x_column], df_qc1[y_column], 1)
polynomial = np.poly1d(coefficients)  
ys = polynomial(df_dg[x_column])
plt.plot(df_dg[x_column], ys, color='red')
plt.show()

#相関係数の計算
correlation = df_dg[x_column].corr(df_qc1[y_column])
print("相関係数",correlation)

# 近似曲線の式
equation = f"y = {polynomial[1]:.2f}x + {polynomial[0]:.2f}"
print("近似曲線の式",equation)
# Out:
# 相関係数 0.5785134858563684
# 近似曲線の式 y = 1.35x + -4.38

# %%
x_column = 'num_vertices'  # x軸にしたい列名
y_column = 'num_gates'  # y軸にしたい列名


plt.scatter(df_dg[x_column], df_qc1[y_column], s=10)
plt.xlabel(f'{x_column} in zx')
plt.ylabel(f'{y_column} in qc')

# 1次関数の近似
coefficients = np.polyfit(df_dg[x_column], df_qc1[y_column], 1)
polynomial = np.poly1d(coefficients)  
ys = polynomial(df_dg[x_column])
plt.plot(df_dg[x_column], ys, color='red')
plt.show()

#相関係数の計算
correlation = df_dg[x_column].corr(df_qc1[y_column])
print("相関係数",correlation)

# 近似曲線の式
equation = f"y = {polynomial[1]:.2f}x + {polynomial[0]:.2f}"
print("近似曲線の式",equation)
# Out:
# 相関係数 0.4050888875393065
# 近似曲線の式 y = 1.36x + -1.97

# %%
x_column = 'num_edge_and_vertices'  # x軸にしたい列名
y_column = 'num_gates'  # y軸にしたい列名


plt.scatter(df_dg[x_column], df_qc1[y_column], s=10)
plt.xlabel(f'{x_column} in zx')
plt.ylabel(f'{y_column} in qc')

# 1次関数の近似
coefficients = np.polyfit(df_dg[x_column], df_qc1[y_column], 1)
polynomial = np.poly1d(coefficients)  
ys = polynomial(df_dg[x_column])
plt.plot(df_dg[x_column], ys, color='red')
plt.show()

#相関係数の計算
correlation = df_dg[x_column].corr(df_qc1[y_column])
print("相関係数",correlation)

# 近似曲線の式
equation = f"y = {polynomial[1]:.2f}x + {polynomial[0]:.2f}"
print("近似曲線の式",equation)
# Out:
# 相関係数 0.5191963168639505
# 近似曲線の式 y = 0.73x + -8.03

# %% [markdown]
# ### num_2qgates in QC と zx の特徴量の関係性

# %%
x_column = 'num_edge'  # x軸にしたい列名
y_column = 'num_2qgates'  # y軸にしたい列名


plt.scatter(df_dg[x_column], df_qc1[y_column], s=10)
plt.xlabel(f'{x_column} in zx')
plt.ylabel(f'{y_column} in qc')

# 1次関数の近似
coefficients = np.polyfit(df_dg[x_column], df_qc1[y_column], 1)
polynomial = np.poly1d(coefficients)  
ys = polynomial(df_dg[x_column])
plt.plot(df_dg[x_column], ys, color='red')
plt.show()

#相関係数の計算
correlation = df_dg[x_column].corr(df_qc1[y_column])
print("相関係数",correlation)

# 近似曲線の式
equation = f"y = {polynomial[1]:.2f}x + {polynomial[0]:.2f}"
print("近似曲線の式",equation)
# Out:
# 相関係数 0.5434213923179424
# 近似曲線の式 y = 1.09x + -20.51

# %%
x_column = 'num_verticallyconnected_edges'  # x軸にしたい列名
y_column = 'num_2qgates'  # y軸にしたい列名


plt.scatter(df_dg[x_column], df_qc1[y_column], s=10)
plt.xlabel(f'{x_column} in zx')
plt.ylabel(f'{y_column} in qc')

# 1次関数の近似
coefficients = np.polyfit(df_dg[x_column], df_qc1[y_column], 1)
polynomial = np.poly1d(coefficients)  
ys = polynomial(df_dg[x_column])
plt.plot(df_dg[x_column], ys, color='red')
plt.show()

#相関係数の計算
correlation = df_dg[x_column].corr(df_qc1[y_column])
print("相関係数",correlation)

# 近似曲線の式
equation = f"y = {polynomial[1]:.2f}x + {polynomial[0]:.2f}"
print("近似曲線の式",equation)
# Out:
# 相関係数 0.6703319793036184
# 近似曲線の式 y = 2.85x + -4.71

# %% [markdown]
# ### num_noncliffords gates in qc と zx 特徴量の関係

# %%
x_column = 'num_noncliffordsphase_vertices'  # x軸にしたい列名
y_column = 'num_noncliffordsgates'  # y軸にしたい列名

plt.scatter(df_dg[x_column], df_qc1[y_column], s=10)
plt.xlabel(f'{x_column} in zx')
plt.ylabel(f'{y_column} in qc')

# 1次関数の近似
coefficients = np.polyfit(df_dg[x_column], df_qc1[y_column], 1)
polynomial = np.poly1d(coefficients)  
ys = polynomial(df_dg[x_column])
plt.plot(df_dg[x_column], ys, color='red')
plt.show()

#相関係数の計算
correlation = df_dg[x_column].corr(df_qc1[y_column])
print("相関係数",correlation)

# 近似曲線の式
equation = f"y = {polynomial[1]:.2f}x + {polynomial[0]:.2f}"
print("近似曲線の式",equation)
# Out:
# 相関係数 0.9582656413673984
# 近似曲線の式 y = 0.95x + 0.20

# %% [markdown]
# ### num H gates in QC と zx 特徴量の関係

# %%
x_column = 'num_edge'  # x軸にしたい列名
y_column = 'num_hadamardgates'  # y軸にしたい列名

plt.scatter(df_dg[x_column], df_qc1[y_column], s=10)
plt.xlabel(f'{x_column} in zx')
plt.ylabel(f'{y_column} in qc')
plt.show()

correlation = df_dg[x_column].corr(df_qc1[y_column])
print(correlation)
# Out:
# 0.2690390617142217

# %%
x_column = 'num_vertices'  # x軸にしたい列名
y_column = 'num_hadamardgates'  # y軸にしたい列名

plt.scatter(df_dg[x_column], df_qc1[y_column], s=10)
plt.xlabel(f'{x_column} in zx')
plt.ylabel(f'{y_column} in qc')
plt.show()

correlation = df_dg[x_column].corr(df_qc1[y_column])
print(correlation)
# Out:
# 0.4127857907466999

# %%
x_column = 'num_edge_and_vertices'  # x軸にしたい列名
y_column = 'num_hadamardgates'  # y軸にしたい列名

plt.scatter(df_dg[x_column], df_qc1[y_column], s=10)
plt.xlabel(f'{x_column} in zx')
plt.ylabel(f'{y_column} in qc')
plt.show()

correlation = df_dg[x_column].corr(df_qc1[y_column])
print(correlation)
# Out:
# 0.3357745961881666
