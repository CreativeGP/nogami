# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ## 20 Qubits, 100 Depth

# %%
df_dg = pd.read_pickle("/home/hinog/src/python3/pyzx_utils/zx_qc/data/pkl/20_100_zxdiagram.pkl")
df_qc = pd.read_pickle("/home/hinog/src/python3/pyzx_utils/zx_qc/data/pkl/20_100_qc.pkl")
df_qc1 = pd.read_pickle("/home/hinog/src/python3/pyzx_utils/zx_qc/data/pkl/20_100_qc1.pkl")

# %% [markdown]
# ### num_gates in QC と zx の特徴量の関係性

# %%
x_column = 'num_edge'  # x軸にしたい列名
y_column = 'num_gates'  # y軸にしたい列名

plt.scatter(df_dg[x_column], df_qc1[y_column], s=10)
plt.xlabel(f'{x_column} in zx')
plt.ylabel(f'{y_column} in qc')

# 1次関数の近似
coefficients = np.polyfit(df_dg[x_column], df_qc1[y_column], 1)
polynomial = np.poly1d(coefficients)  
ys = polynomial(df_dg[x_column])
plt.plot(df_dg[x_column], ys, color='red')
plt.show()

#相関係数の計算
correlation = df_dg[x_column].corr(df_qc1[y_column])
print("相関係数",correlation)

# 近似曲線の式
equation = f"y = {polynomial[1]:.2f}x + {polynomial[0]:.2f}"
print("近似曲線の式",equation)
# Out:
# 相関係数 0.6023325691751227
# 近似曲線の式 y = 1.79x + -38.48

# %%
x_column = 'num_vertices'  # x軸にしたい列名
y_column = 'num_gates'  # y軸にしたい列名


plt.scatter(df_dg[x_column], df_qc1[y_column], s=10)
plt.xlabel(f'{x_column} in zx')
plt.ylabel(f'{y_column} in qc')

# 1次関数の近似
coefficients = np.polyfit(df_dg[x_column], df_qc1[y_column], 1)
polynomial = np.poly1d(coefficients)  
ys = polynomial(df_dg[x_column])
plt.plot(df_dg[x_column], ys, color='red')
plt.show()

#相関係数の計算
correlation = df_dg[x_column].corr(df_qc1[y_column])
print("相関係数",correlation)

# 近似曲線の式
equation = f"y = {polynomial[1]:.2f}x + {polynomial[0]:.2f}"
print("近似曲線の式",equation)
# Out:
# 相関係数 0.39973722578908416
# 近似曲線の式 y = 1.70x + -22.40

# %%
x_column = 'num_edge_and_vertices'  # x軸にしたい列名
y_column = 'num_gates'  # y軸にしたい列名

plt.scatter(df_dg[x_column], df_qc1[y_column], s=10)
plt.xlabel(f'{x_column} in zx')
plt.ylabel(f'{y_column} in qc')

# 1次関数の近似
coefficients = np.polyfit(df_dg[x_column], df_qc1[y_column], 1)
polynomial = np.poly1d(coefficients)  
ys = polynomial(df_dg[x_column])
plt.plot(df_dg[x_column], ys, color='red')
plt.show()

#相関係数の計算
correlation = df_dg[x_column].corr(df_qc1[y_column])
print("相関係数",correlation)

# 近似曲線の式
equation = f"y = {polynomial[1]:.2f}x + {polynomial[0]:.2f}"
print("近似曲線の式",equation)
# Out:
# 相関係数 0.5316998820058323
# 近似曲線の式 y = 0.95x + -44.82

# %% [markdown]
# ### num_2qgates in QC と zx の特徴量の関係性

# %%
x_column = 'num_edge'  # x軸にしたい列名
y_column = 'num_2qgates'  # y軸にしたい列名

plt.scatter(df_dg[x_column], df_qc1[y_column], s=10)
plt.xlabel(f'{x_column} in zx')
plt.ylabel(f'{y_column} in qc')

# 1次関数の近似
coefficients = np.polyfit(df_dg[x_column], df_qc1[y_column], 1)
polynomial = np.poly1d(coefficients)  
ys = polynomial(df_dg[x_column])
plt.plot(df_dg[x_column], ys, color='red')
plt.show()

#相関係数の計算
correlation = df_dg[x_column].corr(df_qc1[y_column])
print("相関係数",correlation)

# 近似曲線の式
equation = f"y = {polynomial[1]:.2f}x + {polynomial[0]:.2f}"
print("近似曲線の式",equation)
# Out:
# 相関係数 0.5591353098089276
# 近似曲線の式 y = 1.46x + -65.56

# %%
x_column = 'num_verticallyconnected_edges'  # x軸にしたい列名
y_column = 'num_2qgates'  # y軸にしたい列名


plt.scatter(df_dg[x_column], df_qc1[y_column], s=10)
plt.xlabel(f'{x_column} in zx')
plt.ylabel(f'{y_column} in qc')

# 1次関数の近似
coefficients = np.polyfit(df_dg[x_column], df_qc1[y_column], 1)
polynomial = np.poly1d(coefficients)  
ys = polynomial(df_dg[x_column])
plt.plot(df_dg[x_column], ys, color='red')
plt.show()

#相関係数の計算
correlation = df_dg[x_column].corr(df_qc1[y_column])
print("相関係数",correlation)

# 近似曲線の式
equation = f"y = {polynomial[1]:.2f}x + {polynomial[0]:.2f}"
print("近似曲線の式",equation)
# Out:
# 相関係数 0.709392303673279
# 近似曲線の式 y = 3.89x + -25.93

# %% [markdown]
# ### num_noncliffords gates in qc と zx 特徴量の関係

# %%
x_column = 'num_noncliffordsphase_vertices'  # x軸にしたい列名
y_column = 'num_noncliffordsgates'  # y軸にしたい列名


plt.scatter(df_dg[x_column], df_qc1[y_column], s=10)
plt.xlabel(f'{x_column} in zx')
plt.ylabel(f'{y_column} in qc')

# 1次関数の近似
coefficients = np.polyfit(df_dg[x_column], df_qc1[y_column], 1)
polynomial = np.poly1d(coefficients)  
ys = polynomial(df_dg[x_column])
plt.plot(df_dg[x_column], ys, color='red')
plt.show()

#相関係数の計算
correlation = df_dg[x_column].corr(df_qc1[y_column])
print("相関係数",correlation)

# 近似曲線の式
equation = f"y = {polynomial[1]:.2f}x + {polynomial[0]:.2f}"
print("近似曲線の式",equation)
# Out:
# 相関係数 0.9633039316380948
# 近似曲線の式 y = 0.96x + 0.28

# %% [markdown]
# ### num H gates in QC と zx 特徴量の関係

# %%
x_column = 'num_edge'  # x軸にしたい列名
y_column = 'num_hadamardgates'  # y軸にしたい列名

plt.scatter(df_dg[x_column], df_qc1[y_column], s=10)
plt.xlabel(f'{x_column} in zx')
plt.ylabel(f'{y_column} in qc')
plt.show()

correlation = df_dg[x_column].corr(df_qc1[y_column])
print(correlation)
# Out:
# 0.24564424300082374

# %%
x_column = 'num_vertices'  # x軸にしたい列名
y_column = 'num_hadamardgates'  # y軸にしたい列名

plt.scatter(df_dg[x_column], df_qc1[y_column], s=10)
plt.xlabel(f'{x_column} in zx')
plt.ylabel(f'{y_column} in qc')
plt.show()

correlation = df_dg[x_column].corr(df_qc1[y_column])
print(correlation)
# Out:
# 0.4198237502547598

# %%
x_column = 'num_edge_and_vertices'  # x軸にしたい列名
y_column = 'num_hadamardgates'  # y軸にしたい列名

plt.scatter(df_dg[x_column], df_qc1[y_column], s=10)
plt.xlabel(f'{x_column} in zx')
plt.ylabel(f'{y_column} in qc')
plt.show()

correlation = df_dg[x_column].corr(df_qc1[y_column])
print(correlation)
# Out:
# 0.3250620930873416
